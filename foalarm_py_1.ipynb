# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.DataFrame()

# %%
df = pd.DataFrame()
df = pd.read_csv('Foalarm_AfirePreFoaling.csv')

# %%
df
# Out:
#                    Date    x    y    z
# 0      15/02/2018 13:20   21  253   90
# 1      15/02/2018 13:20   24  254   90
# 2      15/02/2018 13:20   24  254   90
# 3      15/02/2018 13:20   22  253   92
# 4      15/02/2018 13:20   22  255   89
# 5      15/02/2018 13:21   23  255   89
# 6      15/02/2018 13:21   20  257   86
# 7      15/02/2018 13:21   22  257   84
# 8      15/02/2018 13:21   22  256   83
# 9      15/02/2018 13:21   21  256   85
# 10     15/02/2018 13:21   22  256   84
# 11     15/02/2018 13:22   23  258   82
# 12     15/02/2018 13:22   22  257   82
# 13     15/02/2018 13:22   21  258   81
# 14     15/02/2018 13:22   19  259   81
# 15     15/02/2018 13:22   20  258   81
# 16     15/02/2018 13:22   23  260   81
# 17     15/02/2018 13:23   20  256   83
# 18     15/02/2018 13:23   22  258   81
# 19     15/02/2018 13:23   26  260   75
# 20     15/02/2018 13:23   27  260   76
# 21     15/02/2018 13:23   24  260   74
# 22     15/02/2018 13:23   21  260   73
# ...

# %%
df.head()
# Out:
#                Date   x    y   z
# 0  15/02/2018 13:20  21  253  90
# 1  15/02/2018 13:20  24  254  90
# 2  15/02/2018 13:20  24  254  90
# 3  15/02/2018 13:20  22  253  92
# 4  15/02/2018 13:20  22  255  89

# %%
df.plot()
plt.show()

# %%
df2 = df[["x", "y", "z"]]

# %%
df2.plot()
plt.show()

# %%
df2.head()
# Out:
#     x    y   z
# 0  21  253  90
# 1  24  254  90
# 2  24  254  90
# 3  22  253  92
# 4  22  255  89

# %%
df.rolling(5)
# Out:
# Rolling [window=5,center=False,axis=0]

# %%
df_win = df.rolling(5)

# %%
df_win.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-a75d15523f92> in <module>()
# ----> 1 df_win.head()
#
# /anaconda/lib/python3.6/site-packages/pandas/core/window.py in __getattr__(self, attr)
#     176
#     177         raise AttributeError("%r object has no attribute %r" %
# --> 178                              (type(self).__name__, attr))
#     179
#     180     def _dir_additions(self):
#
# AttributeError: 'Rolling' object has no attribute 'head'

# %%
df_win.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-ac8c1157382f> in <module>()
# ----> 1 df_win.plot()
#       2 plt.show()
#
# /anaconda/lib/python3.6/site-packages/pandas/core/window.py in __getattr__(self, attr)
#     176
#     177         raise AttributeError("%r object has no attribute %r" %
# --> 178                              (type(self).__name__, attr))
#     179
#     180     def _dir_additions(self):
#
# AttributeError: 'Rolling' object has no attribute 'plot'
